# %%
# Import the libraries
import numpy as np  # Used for numerical computations and working with arrays.
import pandas as pd  # Used for data manipulation and analysis, particularly with structured data.
import matplotlib.pyplot as plt  # Used for creating various types of data visualizations.
import seaborn as sns  # Used for creating attractive and informative statistical graphics.
import time  # Used for measuring time or introducing delays in code.
import os  # Used for interacting with the operating system, like file and directory manipulation.
import re  # Used for pattern matching and manipulating strings based on regular expressions.
import datetime

# %%
def procesar_archivos_en_directorio(ruta_directorio):
    """
    Procesa archivos Excel dentro de una ruta dada que comienzan con "Base_" seguido de un número.
    
    Args:
    - ruta_directorio (str): Ruta al directorio que contiene los archivos a procesar.
    
    Returns:
    - DataFrame: Un conjunto de datos concatenado con el contenido de todos los archivos procesados.
    """
    # Lista todos los archivos en el directorio
    lista_archivos = os.listdir(ruta_directorio)
    print(lista_archivos)
    
    # Inicializa una lista vacía para almacenar DataFrames individuales
    lista_dataframes = []

    # Expresión regular para identificar archivos que siguen el patrón "Base_" seguido de un número
    patron = r'^Base_\d+'

    for nombre_archivo in lista_archivos:
        if re.match(patron, nombre_archivo):
            print(nombre_archivo)
            
            # Leer el archivo Excel principal, omitiendo las primeras 4 filas y usando 2 filas como encabezado
            df_principal = pd.read_excel(os.path.join(ruta_directorio, nombre_archivo), skiprows=4, header=[0, 1])
            
            # Leer las primeras 3 filas del mismo archivo para capturar información adicional
            df_info_adicional = pd.read_excel(os.path.join(ruta_directorio, nombre_archivo), nrows=3)

            # Extraer el número del nombre del archivo
            numero_archivo = re.search(r'(\d+)', nombre_archivo).group(1)
            df_principal['Nombre del Proceso'] = f"proceso {numero_archivo}"
            
            # Capturar información adicional y añadirla al DataFrame principal
            for i in range(3):
                df_principal[df_info_adicional.iloc[i, 0]] = df_info_adicional.iloc[i, 1]

            # Agregar información de metadatos
            df_principal['RECORD_SOURCE'] = nombre_archivo
            fecha_formateada = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
            df_principal['LOAD_DATE'] = fecha_formateada
            
            # Agregar DataFrame procesado a la lista
            lista_dataframes.append(df_principal)
        else:
            print(f"No es base a usar {nombre_archivo}")

    # Concatena todos los DataFrames en uno solo
    dataset_final = pd.concat(lista_dataframes)
    
    return dataset_final

# Uso del código:
ruta = 'Prueba reto'
Base_Total = procesar_archivos_en_directorio(ruta)
Base_permanencia = pd.read_excel(os.path.join(ruta, "Base_permanencia.xlsx"))
# Out:
# ['Base_1.xlsx', 'Base_2.xlsx', 'Base_final_modelo.xlsx', 'Base_permanencia.xlsx']
# Base_1.xlsx
# Base_2.xlsx
# c:\Users\Ian\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# No es base a usar Base_final_modelo.xlsx
# No es base a usar Base_permanencia.xlsx

# %%
Base_Total.shape
# Out:
# (5047, 73)

# %%
Base_Total.columns
# Out:
# MultiIndex([(                                               'Ranking', ...),
#             (                                    'No. Identificación', ...),
#             (                                                'Estado', ...),
#             (                                                'Origen', ...),
#             (                                         'Contratado el', ...),
#             (                                             'Etiquetas', ...),
#             (      'Fecha de Ingreso a Proceso\n(Zona horaria GMT 0)', ...),
#             ('Fecha de Finalización de Proceso\n(Zona horaria GMT 0)', ...),
#             (                                                'Ciudad', ...),
#             (                                                'Género', ...),
#             (                                          'Estado Civil', ...),
#             (                                                  'Edad', ...),
#             (                                          'Discapacidad', ...),
#             (                                   'Reubicación laboral', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                        'Habilidades\nHabilidad (Nivel)', ...),
#             (                               'Idiomas\nIdioma (Nivel)', ...),
#             (                                 'Motivadores Laborales', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                               'Resolución de problemas', ...),
#             (                               'Resolución de problemas', ...),
#             (                               'Resolución de problemas', ...),
#             (                               'Resolución de problemas', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                    'Nombre del Proceso', ...),
#             (                                     'Nombre del Perfil', ...),
#             (                         'Inicio \n(Zona horaria GMT 0)', ...),
#             (                            'Fin \n(Zona horaria GMT 0)', ...),
#             (                                         'RECORD_SOURCE', ...),
#             (                                             'LOAD_DATE', ...)],
#            )

# %%
Base_Total.shape
# Out:
# (5047, 73)

# %%
pd.set_option('display.max_columns', 78)

# %%
Base_Total.tail(5) #Printing first 5 rows of the Base_Total
# Out:
#                 Ranking No. Identificación             Estado  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
# 4968               5075         ID10004106          TERMINADO
# 4969               5076         ID10001314          TERMINADO
# 4970               5077         ID10002337          TERMINADO
# 4971               5078         ID10001337          TERMINADO
# 4972               5079         ID10004230          TERMINADO
#
#                  Origen      Contratado el          Etiquetas  \
#      Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 4968             Manual                NaN                NaN
# 4969             Manual                NaN                NaN
# 4970             Manual                NaN                NaN
# 4971             Manual                NaN                NaN
# 4972             Manual                NaN                NaN
#
#      Fecha de Ingreso a Proceso\n(Zona horaria GMT 0)  \
#                                    Unnamed: 6_level_1
# 4968                              2022-08-16 17:35:00
# 4969                              2022-06-01 02:59:00
# 4970                              2022-08-24 17:49:00
# 4971                              2022-09-01 18:50:00
# 4972                              2022-08-24 17:49:00
#
#      Fecha de Finalización de Proceso\n(Zona horaria GMT 0)  \
#                                          Unnamed: 7_level_1
# 4968                                2022-08-16 21:44:00
# 4969                                2022-06-19 18:08:00
# 4970                                2022-08-24 18:35:00
# 4971                                2022-09-05 17:15:00
# 4972                                                NaT
#
#                  Ciudad             Género        Estado Civil  \
#      Unnamed: 8_level_1 Unnamed: 9_level_1 Unnamed: 10_level_1
# 4968               LIMA           FEMENINO            CASADO/A
# 4969               LIMA           FEMENINO           SOLTERO/A
# 4970               LIMA          MASCULINO           SOLTERO/A
# 4971               LIMA          MASCULINO           SOLTERO/A
# 4972               LIMA           FEMENINO           SOLTERO/A
#
#                     Edad        Discapacidad Reubicación laboral  \
#      Unnamed: 11_level_1 Unnamed: 12_level_1 Unnamed: 13_level_1
# 4968                38.0                  No                  No
# 4969                18.0                  No                  No
# 4970                20.0                  No                  No
# 4971                26.0                  No                  Sí
# 4972                36.0                  No                  No
#
#                      Última Experiencia  \
#                                 Empresa
# 4968                                NaN
# 4969  Restaurante EL BUEN GUSTO y chifa
# 4970                Executive solutions
# 4971                                NaN
# 4972                     Imperio el sol
#
#                                                                           \
#                                                Cargo    Inicio       Fin
# 4968                                             NaN       NaN       NaN
# 4969                             ATENCION AL CLIENTE  01/01/22  01/12/22
# 4970        OPERADOR DE PRODUCCION U OPERADOR BASICO  01/09/22  01/05/23
# 4971                                             NaN       NaN       NaN
# 4972  Mis experiencias laborales atención al cliente  01/05/09  01/11/10
#
#                                                          \
#                                             Actividades
# 4968                                                NaN
# 4969                 Me dedicaba atender a las personas
# 4970  Operador de productos tissue cargo paletisador...
# 4971                                                NaN
# 4972  Soy una persona muy positiva muy dinamica un c...
#
#                  Habilidades\nHabilidad (Nivel) Idiomas\nIdioma (Nivel)  \
#                             Unnamed: 19_level_1     Unnamed: 20_level_1
# 4968                                        NaN                     NaN
# 4969  Computer (Medio),trabajo en equipo (Alto)                     NaN
# 4970                                        NaN    Español (Intermedio)
# 4971                                        NaN                     NaN
# 4972             contratacion permanente (Alto)     Inglés (Intermedio)
#
#                                   Motivadores Laborales  \
#                                     Unnamed: 21_level_1
# 4968                                                NaN
# 4969  1.BUEN TRABAJO EN EQUIPO\n2.BUEN CLIMA DE TRAB...
# 4970  1.BONIFICACIONES POR BUEN DESEMPEÑO\n2.BUEN TR...
# 4971                                                NaN
# 4972  1.BUEN CLIMA DE TRABAJO\n2.BUEN TRABAJO EN EQU...
#
#                              Preguntas filtro  \
#      Indícanos el género que figura en tu DNI
# 4968                                 Femenino
# 4969                                 Femenino
# 4970                                Masculino
# 4971                                Masculino
# 4972                                 Femenino
#
#                                                                            \
#      Indícanos tu nivel educativo alcanzado Indícanos tu ubicación actual
# 4968                    Secundaria completa                          Lima
# 4969                    Secundaria completa                          Lima
# 4970                       Técnica completa                          Lima
# 4971                    Secundaria completa                          Lima
# 4972                     Técnico incompleta                          Lima
#
#                                                                \
#      Indícanos tu estado civil ¿Estas estudiando actualmente?
# 4968                    Casado                             No
# 4969                   Soltero                             No
# 4970                   Soltero                             No
# 4971                   Soltero                             No
# 4972                   Soltero                             No
#
#      Calidad del trabajo                               \
#                    Valor Esperado Brecha Cumplimiento
# 4968                0.35      6.0  -5.65         0.43
# 4969                0.35      6.0  -5.65         0.43
# 4970                0.35      6.0  -5.65         0.43
# 4971                0.35      6.0  -5.65         0.43
# 4972                0.35      6.0  -5.65         0.43
#
#      Desarrollo de relaciones                               \
#                         Valor Esperado Brecha Cumplimiento
# 4968                     0.56      6.0  -5.44         0.46
# 4969                     0.56      6.0  -5.44         0.46
# 4970                     0.00      6.0  -6.00         0.40
# 4971                     1.67      6.0  -4.33         0.57
# 4972                     0.00      6.0  -6.00         0.40
#
#      Escrupulosidad/Minuciosidad                               \
#                            Valor Esperado Brecha Cumplimiento
# 4968                        0.92      6.0  -5.08         0.49
# 4969                        0.92      6.0  -5.08         0.49
# 4970                        0.92      6.0  -5.08         0.49
# 4971                        0.92      6.0  -5.08         0.49
# 4972                        1.43      6.0  -4.57         0.54
#
#      Flexibilidad y Adaptabilidad                               \
#                             Valor Esperado Brecha Cumplimiento
# 4968                         1.26      6.0  -4.74         0.53
# 4969                         0.65      6.0  -5.35         0.47
# 4970                         1.26      6.0  -4.74         0.53
# 4971                         0.17      6.0  -5.83         0.42
# 4972                         0.65      6.0  -5.35         0.47
#
#      Orden y la calidad                              Orientación al Logro  \
#                   Valor Esperado Brecha Cumplimiento                Valor
# 4968                2.0      6.0   -4.0          0.6                 0.00
# 4969                2.0      6.0   -4.0          0.6                 0.00
# 4970                2.0      6.0   -4.0          0.6                 0.00
# 4971                1.0      6.0   -5.0          0.5                 0.00
# 4972                1.0      6.0   -5.0          0.5                 1.15
#
#                                   Pensamiento Analítico                  \
#      Esperado Brecha Cumplimiento                 Valor Esperado Brecha
# 4968      6.0  -6.00         0.40                  0.74      6.0  -5.26
# 4969      6.0  -6.00         0.40                  0.74      6.0  -5.26
# 4970      6.0  -6.00         0.40                  0.00      6.0  -6.00
# 4971      6.0  -6.00         0.40                  0.74      6.0  -5.26
# 4972      6.0  -4.85         0.52                  0.00      6.0  -6.00
#
#                   Resolución de problemas                               \
#      Cumplimiento                   Valor Esperado Brecha Cumplimiento
# 4968         0.47                    0.56      6.0  -5.44         0.46
# 4969         0.47                    0.56      6.0  -5.44         0.46
# 4970         0.40                    0.00      6.0  -6.00         0.40
# 4971         0.47                    0.56      6.0  -5.44         0.46
# 4972         0.40                    0.00      6.0  -6.00         0.40
#
#      Tesón y disciplina                              Trabajo en equipo  \
#                   Valor Esperado Brecha Cumplimiento             Valor
# 4968               0.56      6.0  -5.44         0.46              0.00
# 4969               0.56      6.0  -5.44         0.46              0.00
# 4970               0.56      6.0  -5.44         0.46              1.25
# 4971               0.56      6.0  -5.44         0.46              0.00
# 4972               1.17      6.0  -4.83         0.52              0.00
#
#                                   Nombre del Proceso Nombre del Perfil  \
#      Esperado Brecha Cumplimiento
# 4968      6.0  -6.00         0.40          proceso 2            CAJERO
# 4969      6.0  -6.00         0.40          proceso 2            CAJERO
# 4970      6.0  -4.75         0.53          proceso 2            CAJERO
# 4971      6.0  -6.00         0.40          proceso 2            CAJERO
# 4972      6.0  -6.00         0.40          proceso 2            CAJERO
#
#      Inicio \n(Zona horaria GMT 0) Fin \n(Zona horaria GMT 0) RECORD_SOURCE  \
#
# 4968              18/05/2023 16:02           31/08/2025 16:02   Base_2.xlsx
# 4969              18/05/2023 16:02           31/08/2025 16:02   Base_2.xlsx
# 4970              18/05/2023 16:02           31/08/2025 16:02   Base_2.xlsx
# 4971              18/05/2023 16:02           31/08/2025 16:02   Base_2.xlsx
# 4972              18/05/2023 16:02           31/08/2025 16:02   Base_2.xlsx
#
#              LOAD_DATE
#
# 4968  2023-09-24 02:40
# 4969  2023-09-24 02:40
# 4970  2023-09-24 02:40
# 4971  2023-09-24 02:40
# 4972  2023-09-24 02:40

# %%
Base_Total.columns
# Out:
# MultiIndex([(                                               'Ranking', ...),
#             (                                    'No. Identificación', ...),
#             (                                                'Estado', ...),
#             (                                                'Origen', ...),
#             (                                         'Contratado el', ...),
#             (                                             'Etiquetas', ...),
#             (      'Fecha de Ingreso a Proceso\n(Zona horaria GMT 0)', ...),
#             ('Fecha de Finalización de Proceso\n(Zona horaria GMT 0)', ...),
#             (                                                'Ciudad', ...),
#             (                                                'Género', ...),
#             (                                          'Estado Civil', ...),
#             (                                                  'Edad', ...),
#             (                                          'Discapacidad', ...),
#             (                                   'Reubicación laboral', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                                    'Última Experiencia', ...),
#             (                        'Habilidades\nHabilidad (Nivel)', ...),
#             (                               'Idiomas\nIdioma (Nivel)', ...),
#             (                                 'Motivadores Laborales', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                      'Preguntas filtro', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                                   'Calidad del trabajo', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                              'Desarrollo de relaciones', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                           'Escrupulosidad/Minuciosidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                          'Flexibilidad y Adaptabilidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                    'Orden y la calidad', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                  'Orientación al Logro', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                                 'Pensamiento Analítico', ...),
#             (                               'Resolución de problemas', ...),
#             (                               'Resolución de problemas', ...),
#             (                               'Resolución de problemas', ...),
#             (                               'Resolución de problemas', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                    'Tesón y disciplina', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                     'Trabajo en equipo', ...),
#             (                                    'Nombre del Proceso', ...),
#             (                                     'Nombre del Perfil', ...),
#             (                         'Inicio \n(Zona horaria GMT 0)', ...),
#             (                            'Fin \n(Zona horaria GMT 0)', ...),
#             (                                         'RECORD_SOURCE', ...),
#             (                                             'LOAD_DATE', ...)],
#            )

# %%
# Cleaning up the column names
cleaned_columns = []
for col in Base_Total.columns:
    # Check if the second level of the multi-index is a string and contains "Unnamed:"
    if isinstance(col[1], str) and ("Unnamed:" in col[1] or col[1] == "" or col[1] is None):
        cleaned_columns.append(col[0])
    else:
        cleaned_columns.append(col)

Base_Total.columns = cleaned_columns

Base_Total.head(5)
# Out:
#    Ranking No. Identificación     Estado Origen  Contratado el  Etiquetas  \
# 0        1         ID00000001  TERMINADO    NaN            NaN        NaN
# 1        2         ID00000054  TERMINADO    NaN            NaN        NaN
# 2        3         ID00000032  TERMINADO    NaN            NaN        NaN
# 3        4         ID00000002  TERMINADO    NaN            NaN        NaN
# 4        5         ID00000031  TERMINADO    NaN            NaN        NaN
#
#   Fecha de Ingreso a Proceso\n(Zona horaria GMT 0)  \
# 0                              2022-01-16 15:27:00
# 1                              2022-01-30 17:37:00
# 2                              2022-01-18 14:20:00
# 3                              2022-01-23 22:17:00
# 4                              2022-02-02 00:53:00
#
#   Fecha de Finalización de Proceso\n(Zona horaria GMT 0)    Ciudad     Género  \
# 0                                2022-01-23 03:25:00          MALA   FEMENINO
# 1                                2022-02-03 08:47:00          MALA   FEMENINO
# 2                                2022-01-18 18:11:00          MALA  MASCULINO
# 3                                2022-01-24 04:44:00      CHIMBOTE  MASCULINO
# 4                                2022-02-02 16:47:00          MALA   FEMENINO
#
#   Estado Civil  Edad Discapacidad Reubicación laboral  \
# 0    SOLTERO/A  20.0           No                  No
# 1    SOLTERO/A  19.0           No                  No
# 2    SOLTERO/A  23.0           No                  No
# 3    SOLTERO/A  19.0           No                  No
# 4    SOLTERO/A  24.0           No                  No
#
#   (Última Experiencia, Empresa) (Última Experiencia, Cargo)  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                      DON PEPE                    VENDEDOR
# 4            Tiendas efe cañete     ASESOR COMERCIAL RETAIL
#
#   (Última Experiencia, Inicio) (Última Experiencia, Fin)  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                     01/01/21                  01/05/21
# 4                     01/10/22                  01/02/23
#
#                    (Última Experiencia, Actividades)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Mis funciones en esta empresa de venta de abar...
# 4  Estuve como acesora de ventas en la empresa re...
#
#                       Habilidades\nHabilidad (Nivel) Idiomas\nIdioma (Nivel)  \
# 0  contabilidad de proyectos (Alto),liderazgo de ...                     NaN
# 1  Optimismo (Alto),Solidaridad (Alto),Empatía (A...                     NaN
# 2                                                NaN                     NaN
# 3  Retail (Medio),ingles comercial (Bajo),Windows...         Inglés (Básico)
# 4                     contabilidad tributaria (Bajo)                     NaN
#
#                                Motivadores Laborales  \
# 0  1.ESTABILIDAD LABORAL\n2.CAPACITACIÓN Y DESARR...
# 1  1.BUEN LIDER/JEFE\n2.BUEN TRABAJO EN EQUIPO\n3...
# 2                                                NaN
# 3  1.OPORTUNIDADES DE CRECIMIENTO (PLAN DE CARRER...
# 4  1.CAPACITACIÓN Y DESARROLLO PROFESIONAL\n2.DES...
#
#   (Preguntas filtro, Indícanos el género que figura en tu DNI)  \
# 0                                           Femenino
# 1                                           Femenino
# 2                                          Masculino
# 3                                          Masculino
# 4                                           Femenino
#
#   (Preguntas filtro, Indícanos tu nivel educativo alcanzado)  \
# 0                           Universitaria incompleta
# 1                                 Técnico incompleta
# 2                             Universitaria completa
# 3                                Secundaria completa
# 4                                   Técnica completa
#
#   (Preguntas filtro, Indícanos tu ubicación actual)  \
# 0                                        Provincias
# 1                                        Provincias
# 2                                              Lima
# 3                                        Provincias
# 4                                        Provincias
#
#   (Preguntas filtro, Indícanos tu estado civil)  \
# 0                                       Soltero
# 1                                       Soltero
# 2                                       Soltero
# 3                                       Soltero
# 4                                       Soltero
#
#   (Preguntas filtro, ¿Estas estudiando actualmente?)  \
# 0                                                 Si
# 1                                                 Si
# 2                                                 Si
# 3                                                 Si
# 4                                                 No
#
#    (Calidad del trabajo, Valor)  (Calidad del trabajo, Esperado)  \
# 0                           7.0                              7.0
# 1                           5.0                              7.0
# 2                           7.0                              7.0
# 3                           7.0                              7.0
# 4                           5.0                              7.0
#
#    (Calidad del trabajo, Brecha)  (Calidad del trabajo, Cumplimiento)  \
# 0                            0.0                                  1.0
# 1                           -2.0                                  0.8
# 2                            0.0                                  1.0
# 3                            0.0                                  1.0
# 4                           -2.0                                  0.8
#
#    (Desarrollo de relaciones, Valor)  (Desarrollo de relaciones, Esperado)  \
# 0                               6.33                                   7.0
# 1                               7.00                                   7.0
# 2                               6.00                                   7.0
# 3                               4.44                                   7.0
# 4                               7.56                                   7.0
#
#    (Desarrollo de relaciones, Brecha)  \
# 0                               -0.67
# 1                                0.00
# 2                               -1.00
# 3                               -2.56
# 4                                0.56
#
#    (Desarrollo de relaciones, Cumplimiento)  \
# 0                                      0.93
# 1                                      1.00
# 2                                      0.90
# 3                                      0.74
# 4                                      0.94
#
#    (Escrupulosidad/Minuciosidad, Valor)  \
# 0                                   7.0
# 1                                   6.0
# 2                                   9.0
# 3                                   7.0
# 4                                   7.0
#
#    (Escrupulosidad/Minuciosidad, Esperado)  \
# 0                                      7.0
# 1                                      7.0
# 2                                      7.0
# 3                                      7.0
# 4                                      7.0
#
#    (Escrupulosidad/Minuciosidad, Brecha)  \
# 0                                    0.0
# 1                                   -1.0
# 2                                    2.0
# 3                                    0.0
# 4                                    0.0
#
#    (Escrupulosidad/Minuciosidad, Cumplimiento)  \
# 0                                          1.0
# 1                                          0.9
# 2                                          0.8
# 3                                          1.0
# 4                                          1.0
#
#    (Flexibilidad y Adaptabilidad, Valor)  \
# 0                                   5.22
# 1                                   6.22
# 2                                   6.67
# 3                                   6.11
# 4                                   5.56
#
#    (Flexibilidad y Adaptabilidad, Esperado)  \
# 0                                       7.0
# 1                                       7.0
# 2                                       7.0
# 3                                       7.0
# 4                                       7.0
#
#    (Flexibilidad y Adaptabilidad, Brecha)  \
# 0                                   -1.78
# 1                                   -0.78
# 2                                   -0.33
# 3                                   -0.89
# 4                                   -1.44
#
#    (Flexibilidad y Adaptabilidad, Cumplimiento)  (Orden y la calidad, Valor)  \
# 0                                          0.82                          5.0
# 1                                          0.92                          5.0
# 2                                          0.97                          7.0
# 3                                          0.91                          5.0
# 4                                          0.86                          5.0
#
#    (Orden y la calidad, Esperado)  (Orden y la calidad, Brecha)  \
# 0                             7.0                          -2.0
# 1                             7.0                          -2.0
# 2                             7.0                           0.0
# 3                             7.0                          -2.0
# 4                             7.0                          -2.0
#
#    (Orden y la calidad, Cumplimiento)  (Orientación al Logro, Valor)  \
# 0                                 0.8                           5.00
# 1                                 0.8                           4.89
# 2                                 1.0                           3.33
# 3                                 0.8                           5.11
# 4                                 0.8                           5.67
#
#    (Orientación al Logro, Esperado)  (Orientación al Logro, Brecha)  \
# 0                               7.0                           -2.00
# 1                               7.0                           -2.11
# 2                               7.0                           -3.67
# 3                               7.0                           -1.89
# 4                               7.0                           -1.33
#
#    (Orientación al Logro, Cumplimiento)  (Pensamiento Analítico, Valor)  \
# 0                                  0.80                             6.0
# 1                                  0.79                             6.0
# 2                                  0.63                             7.0
# 3                                  0.81                             4.0
# 4                                  0.87                             2.0
#
#    (Pensamiento Analítico, Esperado)  (Pensamiento Analítico, Brecha)  \
# 0                                7.0                             -1.0
# 1                                7.0                             -1.0
# 2                                7.0                              0.0
# 3                                7.0                             -3.0
# 4                                7.0                             -5.0
#
#    (Pensamiento Analítico, Cumplimiento)  (Resolución de problemas, Valor)  \
# 0                                    0.9                              8.22
# 1                                    0.9                              3.44
# 2                                    1.0                              7.11
# 3                                    0.7                              7.44
# 4                                    0.5                              7.67
#
#    (Resolución de problemas, Esperado)  (Resolución de problemas, Brecha)  \
# 0                                  7.0                               1.22
# 1                                  7.0                              -3.56
# 2                                  7.0                               0.11
# 3                                  7.0                               0.44
# 4                                  7.0                               0.67
#
#    (Resolución de problemas, Cumplimiento)  (Tesón y disciplina, Valor)  \
# 0                                     0.88                          5.0
# 1                                     0.64                          6.0
# 2                                     0.99                          0.0
# 3                                     0.96                          4.0
# 4                                     0.93                          4.0
#
#    (Tesón y disciplina, Esperado)  (Tesón y disciplina, Brecha)  \
# 0                             7.0                          -2.0
# 1                             7.0                          -1.0
# 2                             7.0                          -7.0
# 3                             7.0                          -3.0
# 4                             7.0                          -3.0
#
#    (Tesón y disciplina, Cumplimiento)  (Trabajo en equipo, Valor)  \
# 0                                 0.8                         7.0
# 1                                 0.9                         7.0
# 2                                 0.3                         6.5
# 3                                 0.7                         5.5
# 4                                 0.7                         6.5
#
#    (Trabajo en equipo, Esperado)  (Trabajo en equipo, Brecha)  \
# 0                            7.0                          0.0
# 1                            7.0                          0.0
# 2                            7.0                         -0.5
# 3                            7.0                         -1.5
# 4                            7.0                         -0.5
#
#    (Trabajo en equipo, Cumplimiento) Nombre del Proceso Nombre del Perfil  \
# 0                               1.00          proceso 1            CAJERO
# 1                               1.00          proceso 1            CAJERO
# 2                               0.95          proceso 1            CAJERO
# 3                               0.85          proceso 1            CAJERO
# 4                               0.95          proceso 1            CAJERO
#
#   Inicio \n(Zona horaria GMT 0) Fin \n(Zona horaria GMT 0) RECORD_SOURCE  \
# 0              16/01/2023 15:27           04/03/2023 21:27   Base_1.xlsx
# 1              16/01/2023 15:27           04/03/2023 21:27   Base_1.xlsx
# 2              16/01/2023 15:27           04/03/2023 21:27   Base_1.xlsx
# 3              16/01/2023 15:27           04/03/2023 21:27   Base_1.xlsx
# 4              16/01/2023 15:27           04/03/2023 21:27   Base_1.xlsx
#
#           LOAD_DATE
# 0  2023-09-24 02:40
# 1  2023-09-24 02:40
# 2  2023-09-24 02:40
# 3  2023-09-24 02:40
# 4  2023-09-24 02:40

# %%
Base_Total.columns
# Out:
# Index([                                                       'Ranking',
#                                                    'No. Identificación',
#                                                                'Estado',
#                                                                'Origen',
#                                                         'Contratado el',
#                                                             'Etiquetas',
#                      'Fecha de Ingreso a Proceso\n(Zona horaria GMT 0)',
#                'Fecha de Finalización de Proceso\n(Zona horaria GMT 0)',
#                                                                'Ciudad',
#                                                                'Género',
#                                                          'Estado Civil',
#                                                                  'Edad',
#                                                          'Discapacidad',
#                                                   'Reubicación laboral',
#                                       ('Última Experiencia', 'Empresa'),
#                                         ('Última Experiencia', 'Cargo'),
#                                        ('Última Experiencia', 'Inicio'),
#                                           ('Última Experiencia', 'Fin'),
#                                   ('Última Experiencia', 'Actividades'),
#                                        'Habilidades\nHabilidad (Nivel)',
#                                               'Idiomas\nIdioma (Nivel)',
#                                                 'Motivadores Laborales',
#        ('Preguntas filtro', 'Indícanos el género que figura en tu DNI'),
#          ('Preguntas filtro', 'Indícanos tu nivel educativo alcanzado'),
#                   ('Preguntas filtro', 'Indícanos tu ubicación actual'),
#                       ('Preguntas filtro', 'Indícanos tu estado civil'),
#                  ('Preguntas filtro', '¿Estas estudiando actualmente?'),
#                                        ('Calidad del trabajo', 'Valor'),
#                                     ('Calidad del trabajo', 'Esperado'),
#                                       ('Calidad del trabajo', 'Brecha'),
#                                 ('Calidad del trabajo', 'Cumplimiento'),
#                                   ('Desarrollo de relaciones', 'Valor'),
#                                ('Desarrollo de relaciones', 'Esperado'),
#                                  ('Desarrollo de relaciones', 'Brecha'),
#                            ('Desarrollo de relaciones', 'Cumplimiento'),
#                                ('Escrupulosidad/Minuciosidad', 'Valor'),
#                             ('Escrupulosidad/Minuciosidad', 'Esperado'),
#                               ('Escrupulosidad/Minuciosidad', 'Brecha'),
#                         ('Escrupulosidad/Minuciosidad', 'Cumplimiento'),
#                               ('Flexibilidad y Adaptabilidad', 'Valor'),
#                            ('Flexibilidad y Adaptabilidad', 'Esperado'),
#                              ('Flexibilidad y Adaptabilidad', 'Brecha'),
#                        ('Flexibilidad y Adaptabilidad', 'Cumplimiento'),
#                                         ('Orden y la calidad', 'Valor'),
#                                      ('Orden y la calidad', 'Esperado'),
#                                        ('Orden y la calidad', 'Brecha'),
#                                  ('Orden y la calidad', 'Cumplimiento'),
#                                       ('Orientación al Logro', 'Valor'),
#                                    ('Orientación al Logro', 'Esperado'),
#                                      ('Orientación al Logro', 'Brecha'),
#                                ('Orientación al Logro', 'Cumplimiento'),
#                                      ('Pensamiento Analítico', 'Valor'),
#                                   ('Pensamiento Analítico', 'Esperado'),
#                                     ('Pensamiento Analítico', 'Brecha'),
#                               ('Pensamiento Analítico', 'Cumplimiento'),
#                                    ('Resolución de problemas', 'Valor'),
#                                 ('Resolución de problemas', 'Esperado'),
#                                   ('Resolución de problemas', 'Brecha'),
#                             ('Resolución de problemas', 'Cumplimiento'),
#                                         ('Tesón y disciplina', 'Valor'),
#                                      ('Tesón y disciplina', 'Esperado'),
#                                        ('Tesón y disciplina', 'Brecha'),
#                                  ('Tesón y disciplina', 'Cumplimiento'),
#                                          ('Trabajo en equipo', 'Valor'),
#                                       ('Trabajo en equipo', 'Esperado'),
#                                         ('Trabajo en equipo', 'Brecha'),
#                                   ('Trabajo en equipo', 'Cumplimiento'),
#                                                    'Nombre del Proceso',
#                                                     'Nombre del Perfil',
#                                         'Inicio \n(Zona horaria GMT 0)',
#                                            'Fin \n(Zona horaria GMT 0)',
#                                                         'RECORD_SOURCE',
#                                                             'LOAD_DATE'],
#       dtype='object')

# %%
new_columns = []
for col in Base_Total.columns:
    if isinstance(col, tuple):
        new_col = '_'.join(col)
    else:
        new_col = col
    new_columns.append(new_col)

Base_Total.columns = new_columns

# %%
Base_Total.columns
# Out:
# Index(['Ranking', 'No. Identificación', 'Estado', 'Origen', 'Contratado el',
#        'Etiquetas', 'Fecha de Ingreso a Proceso\n(Zona horaria GMT 0)',
#        'Fecha de Finalización de Proceso\n(Zona horaria GMT 0)', 'Ciudad',
#        'Género', 'Estado Civil', 'Edad', 'Discapacidad', 'Reubicación laboral',
#        'Última Experiencia_Empresa', 'Última Experiencia_Cargo',
#        'Última Experiencia_Inicio', 'Última Experiencia_Fin',
#        'Última Experiencia_Actividades', 'Habilidades\nHabilidad (Nivel)',
#        'Idiomas\nIdioma (Nivel)', 'Motivadores Laborales',
#        'Preguntas filtro_Indícanos el género que figura en tu DNI',
#        'Preguntas filtro_Indícanos tu nivel educativo alcanzado',
#        'Preguntas filtro_Indícanos tu ubicación actual',
#        'Preguntas filtro_Indícanos tu estado civil',
#        'Preguntas filtro_¿Estas estudiando actualmente?',
#        'Calidad del trabajo_Valor', 'Calidad del trabajo_Esperado',
#        'Calidad del trabajo_Brecha', 'Calidad del trabajo_Cumplimiento',
#        'Desarrollo de relaciones_Valor', 'Desarrollo de relaciones_Esperado',
#        'Desarrollo de relaciones_Brecha',
#        'Desarrollo de relaciones_Cumplimiento',
#        'Escrupulosidad/Minuciosidad_Valor',
#        'Escrupulosidad/Minuciosidad_Esperado',
#        'Escrupulosidad/Minuciosidad_Brecha',
#        'Escrupulosidad/Minuciosidad_Cumplimiento',
#        'Flexibilidad y Adaptabilidad_Valor',
#        'Flexibilidad y Adaptabilidad_Esperado',
#        'Flexibilidad y Adaptabilidad_Brecha',
#        'Flexibilidad y Adaptabilidad_Cumplimiento', 'Orden y la calidad_Valor',
#        'Orden y la calidad_Esperado', 'Orden y la calidad_Brecha',
#        'Orden y la calidad_Cumplimiento', 'Orientación al Logro_Valor',
#        'Orientación al Logro_Esperado', 'Orientación al Logro_Brecha',
#        'Orientación al Logro_Cumplimiento', 'Pensamiento Analítico_Valor',
#        'Pensamiento Analítico_Esperado', 'Pensamiento Analítico_Brecha',
#        'Pensamiento Analítico_Cumplimiento', 'Resolución de problemas_Valor',
#        'Resolución de problemas_Esperado', 'Resolución de problemas_Brecha',
#        'Resolución de problemas_Cumplimiento', 'Tesón y disciplina_Valor',
#        'Tesón y disciplina_Esperado', 'Tesón y disciplina_Brecha',
#        'Tesón y disciplina_Cumplimiento', 'Trabajo en equipo_Valor',
#        'Trabajo en equipo_Esperado', 'Trabajo en equipo_Brecha',
#        'Trabajo en equipo_Cumplimiento', 'Nombre del Proceso',
#        'Nombre del Perfil', 'Inicio \n(Zona horaria GMT 0)',
#        'Fin \n(Zona horaria GMT 0)', 'RECORD_SOURCE', 'LOAD_DATE'],
#       dtype='object')

# %%
Base_Total.columns = Base_Total.columns.str.replace('\n', ' ')

# %%
Base_Total.head(5)
# Out:
#    Ranking No. Identificación     Estado Origen  Contratado el  Etiquetas  \
# 0        1         ID00000001  TERMINADO    NaN            NaN        NaN
# 1        2         ID00000054  TERMINADO    NaN            NaN        NaN
# 2        3         ID00000032  TERMINADO    NaN            NaN        NaN
# 3        4         ID00000002  TERMINADO    NaN            NaN        NaN
# 4        5         ID00000031  TERMINADO    NaN            NaN        NaN
#
#   Fecha de Ingreso a Proceso (Zona horaria GMT 0)  \
# 0                             2022-01-16 15:27:00
# 1                             2022-01-30 17:37:00
# 2                             2022-01-18 14:20:00
# 3                             2022-01-23 22:17:00
# 4                             2022-02-02 00:53:00
#
#   Fecha de Finalización de Proceso (Zona horaria GMT 0)    Ciudad     Género  \
# 0                                2022-01-23 03:25:00         MALA   FEMENINO
# 1                                2022-02-03 08:47:00         MALA   FEMENINO
# 2                                2022-01-18 18:11:00         MALA  MASCULINO
# 3                                2022-01-24 04:44:00     CHIMBOTE  MASCULINO
# 4                                2022-02-02 16:47:00         MALA   FEMENINO
#
#   Estado Civil  Edad Discapacidad Reubicación laboral  \
# 0    SOLTERO/A  20.0           No                  No
# 1    SOLTERO/A  19.0           No                  No
# 2    SOLTERO/A  23.0           No                  No
# 3    SOLTERO/A  19.0           No                  No
# 4    SOLTERO/A  24.0           No                  No
#
#   Última Experiencia_Empresa Última Experiencia_Cargo  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                   DON PEPE                 VENDEDOR
# 4         Tiendas efe cañete  ASESOR COMERCIAL RETAIL
#
#   Última Experiencia_Inicio Última Experiencia_Fin  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                  01/01/21               01/05/21
# 4                  01/10/22               01/02/23
#
#                       Última Experiencia_Actividades  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Mis funciones en esta empresa de venta de abar...
# 4  Estuve como acesora de ventas en la empresa re...
#
#                        Habilidades Habilidad (Nivel) Idiomas Idioma (Nivel)  \
# 0  contabilidad de proyectos (Alto),liderazgo de ...                    NaN
# 1  Optimismo (Alto),Solidaridad (Alto),Empatía (A...                    NaN
# 2                                                NaN                    NaN
# 3  Retail (Medio),ingles comercial (Bajo),Windows...        Inglés (Básico)
# 4                     contabilidad tributaria (Bajo)                    NaN
#
#                                Motivadores Laborales  \
# 0  1.ESTABILIDAD LABORAL\n2.CAPACITACIÓN Y DESARR...
# 1  1.BUEN LIDER/JEFE\n2.BUEN TRABAJO EN EQUIPO\n3...
# 2                                                NaN
# 3  1.OPORTUNIDADES DE CRECIMIENTO (PLAN DE CARRER...
# 4  1.CAPACITACIÓN Y DESARROLLO PROFESIONAL\n2.DES...
#
#   Preguntas filtro_Indícanos el género que figura en tu DNI  \
# 0                                           Femenino
# 1                                           Femenino
# 2                                          Masculino
# 3                                          Masculino
# 4                                           Femenino
#
#   Preguntas filtro_Indícanos tu nivel educativo alcanzado  \
# 0                           Universitaria incompleta
# 1                                 Técnico incompleta
# 2                             Universitaria completa
# 3                                Secundaria completa
# 4                                   Técnica completa
#
#   Preguntas filtro_Indícanos tu ubicación actual  \
# 0                                     Provincias
# 1                                     Provincias
# 2                                           Lima
# 3                                     Provincias
# 4                                     Provincias
#
#   Preguntas filtro_Indícanos tu estado civil  \
# 0                                    Soltero
# 1                                    Soltero
# 2                                    Soltero
# 3                                    Soltero
# 4                                    Soltero
#
#   Preguntas filtro_¿Estas estudiando actualmente?  Calidad del trabajo_Valor  \
# 0                                              Si                        7.0
# 1                                              Si                        5.0
# 2                                              Si                        7.0
# 3                                              Si                        7.0
# 4                                              No                        5.0
#
#    Calidad del trabajo_Esperado  Calidad del trabajo_Brecha  \
# 0                           7.0                         0.0
# 1                           7.0                        -2.0
# 2                           7.0                         0.0
# 3                           7.0                         0.0
# 4                           7.0                        -2.0
#
#    Calidad del trabajo_Cumplimiento  Desarrollo de relaciones_Valor  \
# 0                               1.0                            6.33
# 1                               0.8                            7.00
# 2                               1.0                            6.00
# 3                               1.0                            4.44
# 4                               0.8                            7.56
#
#    Desarrollo de relaciones_Esperado  Desarrollo de relaciones_Brecha  \
# 0                                7.0                            -0.67
# 1                                7.0                             0.00
# 2                                7.0                            -1.00
# 3                                7.0                            -2.56
# 4                                7.0                             0.56
#
#    Desarrollo de relaciones_Cumplimiento  Escrupulosidad/Minuciosidad_Valor  \
# 0                                   0.93                                7.0
# 1                                   1.00                                6.0
# 2                                   0.90                                9.0
# 3                                   0.74                                7.0
# 4                                   0.94                                7.0
#
#    Escrupulosidad/Minuciosidad_Esperado  Escrupulosidad/Minuciosidad_Brecha  \
# 0                                   7.0                                 0.0
# 1                                   7.0                                -1.0
# 2                                   7.0                                 2.0
# 3                                   7.0                                 0.0
# 4                                   7.0                                 0.0
#
#    Escrupulosidad/Minuciosidad_Cumplimiento  \
# 0                                       1.0
# 1                                       0.9
# 2                                       0.8
# 3                                       1.0
# 4                                       1.0
#
#    Flexibilidad y Adaptabilidad_Valor  Flexibilidad y Adaptabilidad_Esperado  \
# 0                                5.22                                    7.0
# 1                                6.22                                    7.0
# 2                                6.67                                    7.0
# 3                                6.11                                    7.0
# 4                                5.56                                    7.0
#
#    Flexibilidad y Adaptabilidad_Brecha  \
# 0                                -1.78
# 1                                -0.78
# 2                                -0.33
# 3                                -0.89
# 4                                -1.44
#
#    Flexibilidad y Adaptabilidad_Cumplimiento  Orden y la calidad_Valor  \
# 0                                       0.82                       5.0
# 1                                       0.92                       5.0
# 2                                       0.97                       7.0
# 3                                       0.91                       5.0
# 4                                       0.86                       5.0
#
#    Orden y la calidad_Esperado  Orden y la calidad_Brecha  \
# 0                          7.0                       -2.0
# 1                          7.0                       -2.0
# 2                          7.0                        0.0
# 3                          7.0                       -2.0
# 4                          7.0                       -2.0
#
#    Orden y la calidad_Cumplimiento  Orientación al Logro_Valor  \
# 0                              0.8                        5.00
# 1                              0.8                        4.89
# 2                              1.0                        3.33
# 3                              0.8                        5.11
# 4                              0.8                        5.67
#
#    Orientación al Logro_Esperado  Orientación al Logro_Brecha  \
# 0                            7.0                        -2.00
# 1                            7.0                        -2.11
# 2                            7.0                        -3.67
# 3                            7.0                        -1.89
# 4                            7.0                        -1.33
#
#    Orientación al Logro_Cumplimiento  Pensamiento Analítico_Valor  \
# 0                               0.80                          6.0
# 1                               0.79                          6.0
# 2                               0.63                          7.0
# 3                               0.81                          4.0
# 4                               0.87                          2.0
#
#    Pensamiento Analítico_Esperado  Pensamiento Analítico_Brecha  \
# 0                             7.0                          -1.0
# 1                             7.0                          -1.0
# 2                             7.0                           0.0
# 3                             7.0                          -3.0
# 4                             7.0                          -5.0
#
#    Pensamiento Analítico_Cumplimiento  Resolución de problemas_Valor  \
# 0                                 0.9                           8.22
# 1                                 0.9                           3.44
# 2                                 1.0                           7.11
# 3                                 0.7                           7.44
# 4                                 0.5                           7.67
#
#    Resolución de problemas_Esperado  Resolución de problemas_Brecha  \
# 0                               7.0                            1.22
# 1                               7.0                           -3.56
# 2                               7.0                            0.11
# 3                               7.0                            0.44
# 4                               7.0                            0.67
#
#    Resolución de problemas_Cumplimiento  Tesón y disciplina_Valor  \
# 0                                  0.88                       5.0
# 1                                  0.64                       6.0
# 2                                  0.99                       0.0
# 3                                  0.96                       4.0
# 4                                  0.93                       4.0
#
#    Tesón y disciplina_Esperado  Tesón y disciplina_Brecha  \
# 0                          7.0                       -2.0
# 1                          7.0                       -1.0
# 2                          7.0                       -7.0
# 3                          7.0                       -3.0
# 4                          7.0                       -3.0
#
#    Tesón y disciplina_Cumplimiento  Trabajo en equipo_Valor  \
# 0                              0.8                      7.0
# 1                              0.9                      7.0
# 2                              0.3                      6.5
# 3                              0.7                      5.5
# 4                              0.7                      6.5
#
#    Trabajo en equipo_Esperado  Trabajo en equipo_Brecha  \
# 0                         7.0                       0.0
# 1                         7.0                       0.0
# 2                         7.0                      -0.5
# 3                         7.0                      -1.5
# 4                         7.0                      -0.5
#
#    Trabajo en equipo_Cumplimiento Nombre del Proceso Nombre del Perfil  \
# 0                            1.00          proceso 1            CAJERO
# 1                            1.00          proceso 1            CAJERO
# 2                            0.95          proceso 1            CAJERO
# 3                            0.85          proceso 1            CAJERO
# 4                            0.95          proceso 1            CAJERO
#
#   Inicio  (Zona horaria GMT 0) Fin  (Zona horaria GMT 0) RECORD_SOURCE  \
# 0             16/01/2023 15:27          04/03/2023 21:27   Base_1.xlsx
# 1             16/01/2023 15:27          04/03/2023 21:27   Base_1.xlsx
# 2             16/01/2023 15:27          04/03/2023 21:27   Base_1.xlsx
# 3             16/01/2023 15:27          04/03/2023 21:27   Base_1.xlsx
# 4             16/01/2023 15:27          04/03/2023 21:27   Base_1.xlsx
#
#           LOAD_DATE
# 0  2023-09-24 02:40
# 1  2023-09-24 02:40
# 2  2023-09-24 02:40
# 3  2023-09-24 02:40
# 4  2023-09-24 02:40

# %%
# Lista de competencias que quieres revisar
competencias = ["Calidad del trabajo", 
                "Desarrollo de relaciones", 
                "Escrupulosidad/Minuciosidad", 
                "Flexibilidad y Adaptabilidad", 
                "Orden y la calidad", 
                "Orientación al Logro", 
                "Pensamiento Analítico", 
                "Resolución de problemas", 
                "Tesón y disciplina", 
                "Trabajo en equipo"]

# Categorías de las competencias a verificar
categorias = ["_Valor", "_Esperado", "_Brecha", "_Cumplimiento"]

# Construye una máscara para filtrar las filas
mask = True
for competencia in competencias:
    for categoria in categorias:
        columna = f"{competencia}{categoria}"
        mask &= Base_Total[columna].notna()

# Elimina las filas usando la máscara inversa (con ~)
Base_Total.drop(Base_Total[~mask].index, inplace=True)

# %%
Base_Total.shape
# Out:
# (5040, 73)

# %%
Base_Total["Fecha de Finalización de Proceso (Zona horaria GMT 0)"] = Base_Total["Fecha de Finalización de Proceso (Zona horaria GMT 0)"].fillna(Base_Total["Fecha de Ingreso a Proceso (Zona horaria GMT 0)"])

# %%
# Ordena el DataFrame por 'Fecha de Finalización de Proceso (Zona horaria GMT 0)' de manera descendente
Base_Total = Base_Total.sort_values(by='Fecha de Finalización de Proceso (Zona horaria GMT 0)', ascending=False)

# Elimina duplicados por 'No. Identificación' y se queda con el primer registro (el más reciente debido al ordenamiento previo)
Base_Total = Base_Total.drop_duplicates(subset='No. Identificación', keep='first')

# %%
Base_Total.shape
# Out:
# (4975, 73)

# %%
current_datetime = datetime.datetime.now()
formatted_datetime = current_datetime.strftime("%Y-%m-%d %H:%M")  # Formatea la fecha y hora actual
Base_Total['PROCESS_DATA'] = formatted_datetime
# Obtener el nombre de usuario de Windows
windows_username = os.getlogin()

# Establecer el valor de la columna CREATION_USER
Base_Total['CREATION_USER'] = windows_username

# %%
Base_Total["No. Identificación"]=Base_Total["No. Identificación"].str.replace(' ', '', regex=True)
Base_permanencia["No. Identificación"]=Base_permanencia["No. Identificación"].str.replace(' ', '', regex=True)
Base_Total=pd.merge(Base_Total,Base_permanencia,how='inner',on='No. Identificación')

# %%
Base_Total.columns
# Out:
# Index(['Ranking', 'No. Identificación', 'Estado', 'Origen', 'Contratado el',
#        'Etiquetas', 'Fecha de Ingreso a Proceso (Zona horaria GMT 0)',
#        'Fecha de Finalización de Proceso (Zona horaria GMT 0)', 'Ciudad',
#        'Género', 'Estado Civil', 'Edad', 'Discapacidad', 'Reubicación laboral',
#        'Última Experiencia_Empresa', 'Última Experiencia_Cargo',
#        'Última Experiencia_Inicio', 'Última Experiencia_Fin',
#        'Última Experiencia_Actividades', 'Habilidades Habilidad (Nivel)',
#        'Idiomas Idioma (Nivel)', 'Motivadores Laborales',
#        'Preguntas filtro_Indícanos el género que figura en tu DNI',
#        'Preguntas filtro_Indícanos tu nivel educativo alcanzado',
#        'Preguntas filtro_Indícanos tu ubicación actual',
#        'Preguntas filtro_Indícanos tu estado civil',
#        'Preguntas filtro_¿Estas estudiando actualmente?',
#        'Calidad del trabajo_Valor', 'Calidad del trabajo_Esperado',
#        'Calidad del trabajo_Brecha', 'Calidad del trabajo_Cumplimiento',
#        'Desarrollo de relaciones_Valor', 'Desarrollo de relaciones_Esperado',
#        'Desarrollo de relaciones_Brecha',
#        'Desarrollo de relaciones_Cumplimiento',
#        'Escrupulosidad/Minuciosidad_Valor',
#        'Escrupulosidad/Minuciosidad_Esperado',
#        'Escrupulosidad/Minuciosidad_Brecha',
#        'Escrupulosidad/Minuciosidad_Cumplimiento',
#        'Flexibilidad y Adaptabilidad_Valor',
#        'Flexibilidad y Adaptabilidad_Esperado',
#        'Flexibilidad y Adaptabilidad_Brecha',
#        'Flexibilidad y Adaptabilidad_Cumplimiento', 'Orden y la calidad_Valor',
#        'Orden y la calidad_Esperado', 'Orden y la calidad_Brecha',
#        'Orden y la calidad_Cumplimiento', 'Orientación al Logro_Valor',
#        'Orientación al Logro_Esperado', 'Orientación al Logro_Brecha',
#        'Orientación al Logro_Cumplimiento', 'Pensamiento Analítico_Valor',
#        'Pensamiento Analítico_Esperado', 'Pensamiento Analítico_Brecha',
#        'Pensamiento Analítico_Cumplimiento', 'Resolución de problemas_Valor',
#        'Resolución de problemas_Esperado', 'Resolución de problemas_Brecha',
#        'Resolución de problemas_Cumplimiento', 'Tesón y disciplina_Valor',
#        'Tesón y disciplina_Esperado', 'Tesón y disciplina_Brecha',
#        'Tesón y disciplina_Cumplimiento', 'Trabajo en equipo_Valor',
#        'Trabajo en equipo_Esperado', 'Trabajo en equipo_Brecha',
#        'Trabajo en equipo_Cumplimiento', 'Nombre del Proceso',
#        'Nombre del Perfil', 'Inicio  (Zona horaria GMT 0)',
#        'Fin  (Zona horaria GMT 0)', 'RECORD_SOURCE', 'LOAD_DATE',
#        'PROCESS_DATA', 'CREATION_USER', 'Permanencia>6meses'],
#       dtype='object')

# %%
Base_Total = Base_Total.sort_values(by=["Nombre del Proceso",'Ranking'], ascending=True)

# %%
Base_Total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4975 entries, 4941 to 1349
# Data columns (total 76 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Ranking                                                    4975 non-null   int64
#  1   No. Identificación                                         4975 non-null   object
#  2   Estado                                                     4975 non-null   object
#  3   Origen                                                     4912 non-null   object
#  4   Contratado el                                              0 non-null      float64
#  5   Etiquetas                                                  0 non-null      float64
#  6   Fecha de Ingreso a Proceso (Zona horaria GMT 0)            4975 non-null   datetime64[ns]
#  7   Fecha de Finalización de Proceso (Zona horaria GMT 0)      4975 non-null   datetime64[ns]
#  8   Ciudad                                                     4966 non-null   object
#  9   Género                                                     4971 non-null   object
#  10  Estado Civil                                               4966 non-null   object
#  11  Edad                                                       4966 non-null   float64
#  12  Discapacidad                                               4961 non-null   object
#  13  Reubicación laboral                                        4974 non-null   object
#  14  Última Experiencia_Empresa                                 2996 non-null   object
#  15  Última Experiencia_Cargo                                   2996 non-null   object
#  16  Última Experiencia_Inicio                                  2996 non-null   object
#  17  Última Experiencia_Fin                                     2751 non-null   object
#  18  Última Experiencia_Actividades                             2992 non-null   object
#  19  Habilidades Habilidad (Nivel)                              2433 non-null   object
#  20  Idiomas Idioma (Nivel)                                     2626 non-null   object
#  21  Motivadores Laborales                                      3200 non-null   object
#  22  Preguntas filtro_Indícanos el género que figura en tu DNI  4974 non-null   object
#  23  Preguntas filtro_Indícanos tu nivel educativo alcanzado    4974 non-null   object
#  24  Preguntas filtro_Indícanos tu ubicación actual             4974 non-null   object
#  25  Preguntas filtro_Indícanos tu estado civil                 4974 non-null   object
#  26  Preguntas filtro_¿Estas estudiando actualmente?            4974 non-null   object
#  27  Calidad del trabajo_Valor                                  4975 non-null   float64
#  28  Calidad del trabajo_Esperado                               4975 non-null   float64
#  29  Calidad del trabajo_Brecha                                 4975 non-null   float64
#  30  Calidad del trabajo_Cumplimiento                           4975 non-null   float64
#  31  Desarrollo de relaciones_Valor                             4975 non-null   float64
#  32  Desarrollo de relaciones_Esperado                          4975 non-null   float64
#  33  Desarrollo de relaciones_Brecha                            4975 non-null   float64
#  34  Desarrollo de relaciones_Cumplimiento                      4975 non-null   float64
#  35  Escrupulosidad/Minuciosidad_Valor                          4975 non-null   float64
#  36  Escrupulosidad/Minuciosidad_Esperado                       4975 non-null   float64
#  37  Escrupulosidad/Minuciosidad_Brecha                         4975 non-null   float64
#  38  Escrupulosidad/Minuciosidad_Cumplimiento                   4975 non-null   float64
#  39  Flexibilidad y Adaptabilidad_Valor                         4975 non-null   float64
#  40  Flexibilidad y Adaptabilidad_Esperado                      4975 non-null   float64
#  41  Flexibilidad y Adaptabilidad_Brecha                        4975 non-null   float64
#  42  Flexibilidad y Adaptabilidad_Cumplimiento                  4975 non-null   float64
#  43  Orden y la calidad_Valor                                   4975 non-null   float64
#  44  Orden y la calidad_Esperado                                4975 non-null   float64
#  45  Orden y la calidad_Brecha                                  4975 non-null   float64
#  46  Orden y la calidad_Cumplimiento                            4975 non-null   float64
#  47  Orientación al Logro_Valor                                 4975 non-null   float64
#  48  Orientación al Logro_Esperado                              4975 non-null   float64
#  49  Orientación al Logro_Brecha                                4975 non-null   float64
#  50  Orientación al Logro_Cumplimiento                          4975 non-null   float64
#  51  Pensamiento Analítico_Valor                                4975 non-null   float64
#  52  Pensamiento Analítico_Esperado                             4975 non-null   float64
#  53  Pensamiento Analítico_Brecha                               4975 non-null   float64
#  54  Pensamiento Analítico_Cumplimiento                         4975 non-null   float64
#  55  Resolución de problemas_Valor                              4975 non-null   float64
#  56  Resolución de problemas_Esperado                           4975 non-null   float64
#  57  Resolución de problemas_Brecha                             4975 non-null   float64
#  58  Resolución de problemas_Cumplimiento                       4975 non-null   float64
#  59  Tesón y disciplina_Valor                                   4975 non-null   float64
#  60  Tesón y disciplina_Esperado                                4975 non-null   float64
#  61  Tesón y disciplina_Brecha                                  4975 non-null   float64
#  62  Tesón y disciplina_Cumplimiento                            4975 non-null   float64
#  63  Trabajo en equipo_Valor                                    4975 non-null   float64
#  64  Trabajo en equipo_Esperado                                 4975 non-null   float64
#  65  Trabajo en equipo_Brecha                                   4975 non-null   float64
#  66  Trabajo en equipo_Cumplimiento                             4975 non-null   float64
#  67  Nombre del Proceso                                         4975 non-null   object
#  68  Nombre del Perfil                                          4975 non-null   object
#  69  Inicio  (Zona horaria GMT 0)                               4975 non-null   object
#  70  Fin  (Zona horaria GMT 0)                                  4975 non-null   object
#  71  RECORD_SOURCE                                              4975 non-null   object
#  72  LOAD_DATE                                                  4975 non-null   object
#  73  PROCESS_DATA                                               4975 non-null   object
#  74  CREATION_USER                                              4975 non-null   object
#  75  Permanencia>6meses                                         4975 non-null   int64
# dtypes: datetime64[ns](2), float64(43), int64(2), object(29)
# memory usage: 2.9+ MB

# %%
Base_Total.to_excel("Modelo_base_consolidado.xlsx",index=False)
